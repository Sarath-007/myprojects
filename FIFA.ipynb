# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv(r'C:\Users\DELL\Documents\data.csv')
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df2=df.head()
df2
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                5 non-null      int64
#  1   ID                        5 non-null      int64
#  2   Name                      5 non-null      object
#  3   Age                       5 non-null      int64
#  4   Photo                     5 non-null      object
#  5   Nationality               5 non-null      object
#  6   Flag                      5 non-null      object
#  7   Overall                   5 non-null      int64
#  8   Potential                 5 non-null      int64
#  9   Club                      5 non-null      object
#  10  Club Logo                 5 non-null      object
#  11  Value                     5 non-null      object
#  12  Wage                      5 non-null      object
#  13  Special                   5 non-null      int64
# ...

# %%
df2['Nationality']
# Out:
# 0    Argentina
# 1     Portugal
# 2       Brazil
# 3        Spain
# 4      Belgium
# Name: Nationality, dtype: object

# %%
df2.iloc[15][19]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-d9c1a72599eb> in <module>
# ----> 1 df2.iloc[15][19]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df2.iloc[4]
# Out:
# Unnamed: 0                                                     4
# ID                                                        192985
# Name                                                K. De Bruyne
# Age                                                           27
# Photo             https://cdn.sofifa.org/players/4/19/192985.png
#                                        ...
# GKHandling                                                    13
# GKKicking                                                      5
# GKPositioning                                                 10
# GKReflexes                                                    13
# Release Clause                                           €196.4M
# Name: 4, Length: 89, dtype: object

# %%
sns.heatmap(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-e0b1d8263ce0> in <module>
# ----> 1 sns.heatmap(df2)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Work Rate', 'Body Type')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-1c8d8e335a74> in <module>
# ...

# %%
sns.barplot(x=df2['Nationality'],y=df2['Stamina'])
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Stamina'>

# %%
df2['Work Rate']
# Out:
# 0    Medium/ Medium
# 1         High/ Low
# 2      High/ Medium
# 3    Medium/ Medium
# 4        High/ High
# Name: Work Rate, dtype: object

# %%
df['International Reputation'].value_counts()
# Out:
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
(df['International Reputation']==5)&(df['Nationality']=='Argentina')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Length: 18207, dtype: bool

# %%
df['Nationality'].value_counts()
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
#                ...
# Andorra           1
# St Lucia          1
# Kuwait            1
# South Sudan       1
# Jordan            1
# Name: Nationality, Length: 164, dtype: int64

# %%
df4=df['Nationality','Potential']
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Nationality', 'Potential')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-30576a3c768c> in <module>
# ...

# %%
df.loc[df.Nationality=='Argentina']
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 0               0  158023        L. Messi   31
# 15             15  211110       P. Dybala   24
# 23             23  153079       S. Agüero   30
# 38             38  167664      G. Higuaín   30
# 43             43  201399       M. Icardi   25
# ...           ...     ...             ...  ...
# 17349       17349  240955        T. Durso   19
# 17355       17355  237125      V. Barbero   17
# 17638       17638  236431      E. Alarcón   25
# 17861       17861  245726   F. Bustamante   19
# 17987       17987  241099  L. Finochietto   21
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15     https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23     https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38     https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# ...

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df_arg=df.Nationality=='Argentina'

# %%
df_arg.value_counts()
# Out:
# False    17270
# True       937
# Name: Nationality, dtype: int64

# %%
df_arg=df.loc[df.Nationality=='Argentina']
df_arg
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 0               0  158023        L. Messi   31
# 15             15  211110       P. Dybala   24
# 23             23  153079       S. Agüero   30
# 38             38  167664      G. Higuaín   30
# 43             43  201399       M. Icardi   25
# ...           ...     ...             ...  ...
# 17349       17349  240955        T. Durso   19
# 17355       17355  237125      V. Barbero   17
# 17638       17638  236431      E. Alarcón   25
# 17861       17861  245726   F. Bustamante   19
# 17987       17987  241099  L. Finochietto   21
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15     https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23     https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38     https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# ...

# %%
df_arg['Wages']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wages'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-fc2c390df227> in <module>
# ----> 1 df_arg['Wages']
#
# ...

# %%
df_arg.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df_arg['Wage']
# Out:
# 0        €565K
# 15       €205K
# 23       €300K
# 38       €245K
# 43       €130K
#          ...
# 17349      €1K
# 17355      €1K
# 17638      €2K
# 17861      €1K
# 17987      €1K
# Name: Wage, Length: 937, dtype: object

# %%
plt.pie(df_arg['Potential'])
plt.figure(figsize=(16,16))

# %%
df_arg.describe()
df_arg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 937 entries, 0 to 17987
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                937 non-null    int64
#  1   ID                        937 non-null    int64
#  2   Name                      937 non-null    object
#  3   Age                       937 non-null    int64
#  4   Photo                     937 non-null    object
#  5   Nationality               937 non-null    object
#  6   Flag                      937 non-null    object
#  7   Overall                   937 non-null    int64
#  8   Potential                 937 non-null    int64
#  9   Club                      936 non-null    object
#  10  Club Logo                 937 non-null    object
#  11  Value                     937 non-null    object
#  12  Wage                      937 non-null    object
# ...

# %%
df_arg['Overall'].unique()
# Out:
# array([94, 89, 88, 87, 85, 84, 82, 81, 80, 79, 78, 77, 76, 75, 74, 73, 72,
#        71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61, 60, 59, 58, 57, 56, 55,
#        54, 53, 52, 51], dtype=int64)

# %%
df_arg1=df_arg.loc[df_arg['Overall']>80]
df_arg1
# Out:
#      Unnamed: 0      ID         Name  Age  \
# 0             0  158023     L. Messi   31
# 15           15  211110    P. Dybala   24
# 23           23  153079    S. Agüero   30
# 38           38  167664   G. Higuaín   30
# 43           43  201399    M. Icardi   25
# 89           89  192366  N. Otamendi   30
# 138         138  183898  A. Di María   30
# 142         142  178562    E. Banega   30
# 151         151  143076     A. Gómez   30
# 255         255  207471   F. Vázquez   29
# 282         282  191180   J. Pastore   29
# 295         295  184144    N. Gaitán   30
# 303         303  179847     F. Fazio   31
# 307         307  170481     E. Garay   31
# 313         313  158963    L. Biglia   32
# 335         335  214997    A. Correa   23
# 375         375  190972    E. Salvio   27
# 380         380  188988   M. Lanzini   25
# 384         384  183900   D. Perotti   29
# 395         395  170368    E. Lamela   26
#
#                                               Photo Nationality  \
# ...

# %%
sns.barplot(x=df_arg1['Body Type'],y=df_arg1['ShotPower'])
# Out:
# <AxesSubplot:xlabel='Body Type', ylabel='ShotPower'>

# %%
df_arg1['Body Type'].unique()
# Out:
# array(['Messi', 'Normal', 'Stocky', 'Lean'], dtype=object)

# %%
df_arg['Positioning'].unique()
# Out:
# array([94., 84., 92., 51., 82., 75., 81., 77., 78., 32., 42., 50., 83.,
#        73., 79., 12., 18., 67., 74., 76., 11., 85., 56., 70., 57., 63.,
#        31., 14., 71., 80., 35., 65., 38., 59., 19., 69., 68., 48., 72.,
#        49., 61., 36.,  7., 10., 34., 62., 28., 55., 40., 20., 29., 45.,
#        60., 66., 13., 17., 43., 54., 26., 16., 41., 15., 46., 44., 58.,
#        27.,  9., 64., 22., 23., 33., 52., 21., 47., 53., 39., 30., 37.,
#         8., 24., 25.,  6., nan,  5.,  4.])

# %%
df['Body Type'].value_counts()
# Out:
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# PLAYER_BODY_TYPE_25        1
# Neymar                     1
# Courtois                   1
# C. Ronaldo                 1
# Messi                      1
# Akinfenwa                  1
# Shaqiri                    1
# Name: Body Type, dtype: int64

# %%
l1=df_arg1['Body Type'].unique()
l1
plt.figure(figsize=(20,20))
plt.pie(df_arg1['Crossing'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2e349ab9280>,
# ...
#  [Text(1.0815803981639474, 0.2004590788852361, ''),
#   Text(0.9404030562561256, 0.5706505864223205, ''),
#   Text(0.7033828968998043, 0.8457260196711694, ''),
#   Text(0.4209517637078701, 1.0162674906889593, ''),
#   Text(0.15784186210684306, 1.0886165287035856, ''),
#   Text(-0.07673215507933807, 1.0973204529110356, ''),
#   Text(-0.3919634077610783, 1.0277960337422611, ''),
#   Text(-0.7252804191942791, 0.82702376842106, ''),
#   Text(-0.9666988394898929, 0.5248746076244253, ''),
#   Text(-1.0860791783296846, 0.17444775263303774, ''),
#   Text(-1.0845154907423453, -0.1839188689066191, ''),
#   Text(-0.9597455989735826, -0.5374833813717771, ''),
#   Text(-0.7812038993893187, -0.7744162108187842, ''),
#   Text(-0.5829111705198046, -0.932852918354888, ''),
#   Text(-0.28470092059772817, -1.0625184166925326, ''),
#   Text(0.06715342803966944, -1.0979482761508035, ''),
#   Text(0.42095181128278386, -1.016267470982784, ''),
# ...

# %%
sns.swarmplot(x=df_arg['Body Type'],y=df_arg['Height'])
